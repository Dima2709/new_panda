# %%
import pandas as pd

df = pd.read_csv('data1.csv')

# %%
df['profit'] = df['revenue'] - df['budget']
for i in range(len(df['release_year'])):
    mass = [j for j in df['release_year'][i] if j.isdigit()]
    df['release_year'][i] = int(''.join(mass))
df
# Out:
# C:\Users\Дима\AppData\Local\Temp/ipykernel_4436/3860382782.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_year'][i] = int(''.join(mass))
#       runtime release_date        imdb_id  \
# 0         124     6/9/2015        0369610
# 1         120    5/13/2015        1392190
# 2         119    3/18/2015  \r\ntt2908446
# 3         137     4/1/2015        2488496
# 4         136   12/15/2015        1663202
# ...       ...          ...            ...
# 1878      104    7/13/2000        0120903
# 1879       95   10/27/2000        0192255
# 1880       88    6/30/2000        0131704
# 1881       94    2/16/2000        0162983
# 1882      105    7/19/2000        0163676
#
#                             original_title  \
# 0                           Jurassic World
# ...

# %%
#27. Какие актеры чаще всего снимаются в одном фильме вместе?
df1 =df[['cast']].apply(lambda x: x.str.split('|').explode())
df1
# Out:
#                      cast
# 0             Chris Pratt
# 0     Bryce Dallas Howard
# 0             Irrfan Khan
# 0       Vincent D'Onofrio
# 0           Nick Robinson
# ...                   ...
# 1882           Susan Ward
# 1882         Lori Heuring
# 1882       Matthew Settle
# 1882        Nathan Bexton
# 1882          Tess Harper
#
# [9401 rows x 1 columns]

# %%
df[['production_companies']].apply(lambda x: x.str.split('|').explode()).production_companies.to_frame().join(df['original_title'].apply(lambda x: len(x.split(' ')))).groupby('production_companies').mean().sort_values(by='original_title').tail(1)
# Out:
#                          original_title
# production_companies
# Four By Two Productions            12.0

# %%
df1.cast[(df1.cast == arg)].to_frame().join(df2.genres).value_counts().head(1)
# Out:
# 6     147
# 11    146
# 7     142
# Name: release_date, dtype: int64

# %%
# Out:
# runtime                                                               138
# release_date                                                    7/19/2002
# imdb_id                                                           0267626
# original_title                                       K-19: The Widowmaker
# genres                                             Thriller|Drama|History
# vote_average                                                          6.0
# budget                                                          100000000
# cast                    Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...
# production_companies    Paramount Pictures|Intermedia Films|National G...
# release_year                                                         2002
# revenue                                                          35168966
# director                                                  Kathryn Bigelow
# profit                                                          -64831034
# ...
